# %% [markdown]
# ## This is a tutorial temp file
# 1) uv venv
# 2) uv pip install ipykernel
# 3) uv pip install -r requirements.txt

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('data.csv')
print("length:",len(df))
df.head()

# %%
np.full((10,3),3)
np.random.randint(5,100,(5,3))
